# %% [markdown]
# # Descriptive Statistics Using Pandas of Kaggle Mental Health Dataset

# %% [markdown]
# In this notebook, we will explore a dataset about student mental health and will evaluate how different groups of students report their mental health status.

# %% [markdown]
# ## Load dataset

# %%
import lib
import pandas as pd

# %%
# get path from current directory to data folder
data = pd.read_csv('../data/student_mental_health.csv')
data.head()
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %% [markdown]
# ## Descriptive Statistics

# %% [markdown]
# We look at overall descriptive statistics from the dataset. These include:
# - Proportion of male vs. female respondants
# - Age: Mean, Median, and Mode
# - Course of study distribution
# - Year of study distribution
# - Marital status distribution
# - Anxiety panic attack, and specialist help distribution

# %% [markdown]
# #### Proportion of male vs. female respondants

# %%
lib.bar_chart(data, 'Choose your gender', 'Gender Distribution', 'Gender', 'Count', color=['pink', 'skyblue'])

# %% [markdown]
# #### Age: Mean, Median, Mode

# %%
# from lib import get_mean_median_mode
# Get mean, median, mode from lib module
mean_val, mode_val, median_val = lib.get_mean_median_mode(data, 'Age')

# print results
print('Mean age: ', mean_val)
print('Median age: ', median_val)
print('Mode age: ', mode_val)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[132], line 3
#       1 # from lib import get_mean_median_mode
#       2 # Get mean, median, mode from lib module
# ----> 3 mean_val, mode_val, median_val = lib.get_mean_median_mode(data, 'Age')
#       5 # print results
#       6 print('Mean age: ', mean_val)
#
# AttributeError: module 'lib' has no attribute 'get_mean_median_mode'

# %% [markdown]
# ## Age: 25th, 50th, 75th percentiles

# %%
# get percentiles
percentile_25, percentile_50, percentile_75 = lib.get_percentiles(data, 'Age')

# print results
print('25th percentile: ', percentile_25)
print('50th percentile: ', percentile_50)
print('75th percentile: ', percentile_75)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[99], line 2
#       1 # get percentiles
# ----> 2 percentile_25, percentile_50, percentile_75 = lib.get_percentiles(data, 'Age')
#       4 # print results
#       5 print('25th percentile: ', percentile_25)
#
# AttributeError: module 'lib' has no attribute 'get_percentiles'

# %% [markdown]
# ## Course of study distribution

# %%
# bar chart of the course of study
bar_chart(data, 'What is your course?', 'Course of Study Distribution',
              'Course of Study', 'Count', color='blue')

# %% [markdown]
# ## Year of study distribution

# %%
# Create bar chart of the year of study
data['Your current year of Study'] = data['Your current year of Study'].str.upper()
bar_chart(data, 'Your current year of Study', 'Year of Study Distribution',
                'Year of Study', 'Count', color='green')

# %% [markdown]
# ## Marital Status Distribution

# %%
# Create bar chart of the year of marital status
bar_chart(data, 'Marital status', 'Marital Status Distribution',
                'Marital Status', 'Count', color=['blue', 'red'])

# %% [markdown]
# ## Depression distribution

# %%
# Create bar chart for depression
bar_chart(data, 'Do you have Depression?', 'Depression Distribution',
                'Depression', 'Count', color=['blue', 'red'])

# %% [markdown]
# ## Anxiety distribution

# %%
# Create bar chart for anxiety
bar_chart(data, 'Do you have Anxiety?', 'Anxiety Distribution',
                'Anxiety', 'Count', color=['blue', 'red'])

# %% [markdown]
# ## Panic attacks distribution

# %%
# create bar chart for panic attack
bar_chart(data, 'Do you have Panic attack?', 'Panic Attack Distribution',
                'Panic Attack', 'Count', color=['blue', 'red'])

# %% [markdown]
# # Insights

# %% [markdown]
# Now we will investigate a few questions:
# - What are the majors that report the highest panic attacks?
# - Is there a correlation between marital status and depression?
# - What is the relationship between CGPA and anxiety?

# %% [markdown]
# ### Majors with highest panic attacks
